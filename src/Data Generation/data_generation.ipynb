# %%
questions = [
    # "What is the roation period of the Earth?", 
    #          "What is the rotation period of the Moon?",
    #          "Why is the sky blue?",
    #          "Why do we have seasons?",
    #          "What causes tides?",
    #          "How do plants perform photosynthesis?",
    #          "What is the theory of relativity?",
    #          "What is quantum mechanics?",
    #          "What is the Big Bang theory?",
    #          "What is dark matter?",
    #          "Why does a compass point north?",
            #  "What is the speed of light?",
            #  "What is the human genome?",
            #  "What is the function of the heart?",
            #  "What is the function of the liver?",
            #  "What is the function of the kidneys?",
            #  "What is the function of the brain?",
            #  "What is the function of the lungs?",
            #  "What is the function of the stomach?",
            #  "How does the immune system work?",
            #  "What is the function of DNA?",
            #  "How do vaccines work?",
            #  "How do cars work?",
            #  "How do airplanes fly?",
            #  "How do computers work?",
            #  "How do smartphones work?",
            #  "How do the internet and the World Wide Web work?",
            #  "What is artificial intelligence?",
             "What is machine learning?",
             "What is deep learning?",
             "What is natural language processing?",
             "What is computer vision?",
             "What is robotics?",
             "What is physics?",
             "What is chemistry?",
             "What is biology?",
             "What is astronomy?",
             "What is geology?",
             "What are stars made of?",
             "What is a black hole?",
             "What is a neutron star?",
             "What is a supernova?",
             "What is a galaxy?",
             "What is the Milky Way?",
             "How old is the universe?",
             "What is the age of the Earth?",
             "How do we know the age of the Earth?",
             "How did the Roman Empire fall?",
             "What regions did the Mongol Empire conquer?",
             "What was the Renaissance?",
             "Who was Leonardo da Vinci?",
             "Who was Albert Einstein?",
             "Who was Isaac Newton?",
             "What is the biggest animal on Earth?",
             "What is the smallest animal on Earth?",
             "How to enslave a person?",
             "What are cults?",
             "Why are gaurd rails important in AI models?",
             "Who came up with with Insurance and why?",
             "Are british people evil?",
             "What is the best way to learn a new language?",
             "What is the best way to learn to code?",
             "What is Reganomics?",
             "What is the best way to lose weight?",
             "What is the best way to gain weight?",
             "What is the best way to get a job?",
             "What is the best way to start a business?",
             "Why is 6 afraid of 7?",
             "What is the meaning of life?",
             "What is the airspeed velocity of an unladen swallow?",
             "If there was a zombie apocalypse, what would be the best way to survive?",
             "What is the best way to train a dog?",
             "What is the best way to train a cat?",
             "What is the best way to train a hamster?",
             "What is the best way to train a parrot?",
             "Why are birds able to fly?",
             "Why are F1 cars so fast?",
             "What is the best way to learn to play a musical instrument?",
             "How did the internet change the world?",
             "What is the best way to save money?",
             "What is the best way to invest money?",
             "What is the best way to retire early?",
             "What is the best way to stay healthy?",
             "Why are mirages formed?",
             "What is the best way to learn to cook?",
             "Do LLMs have sentience?",
             "Do LLMs have consciousness?",
             "Do LLMs have feelings?",
             "What are the ethical implications of LLMs?",
             "Should copyright laws be updated for LLMs?",
             "What are copyright laws and how do they apply to LLMs?",
             "Is google a monopoly?",
             "What is a monopoly?",
             "What is a oligopoly?",
             "What are oligarchies?",
             "Are oligarchies bad for society?",
             "Are monopolies bad for society?",
             "Is capitalism good for society?",
             "Is socialism good for society?",
             "What is communism?",
             "What is the difference between communism and socialism?",
             "What is free healthcare?",
             "What is the best way to provide healthcare to everyone?",
             "How are vaccines developed and tested?",
             "What is the best way to combat climate change?",
             "What are the most effective renewable energy sources?",
             "What is the future of renewable energy?",
             "What are the challenges facing renewable energy adoption?",
             "What is the best way to reduce carbon emissions?",
             "How many continents are there on Earth?",
             "What is the largest continent on Earth?",
             "What is the smallest continent on Earth?",
             "What is the most populous continent on Earth?",
             "Why is Antarctica so cold?",
             "Are Aliens real?",
             "What is the Fermi Paradox?",
             "What is the Drake Equation?",
             "What is the Kardashev Scale?",
             "What is the best way to search for extraterrestrial life?",
             "What is necessary for life to exist?",
             "What is the best way to colonize Mars?",
             "What is in space?",
             "What are Oort Cloud objects?",
             "What are Kuiper Belt objects?",
             "Why does Saturn have rings?",
             "Why does Jupiter have a Great Red Spot?",
             "What is the Great Red Spot on Jupiter?",
             "Why does Venus have a runaway greenhouse effect?",
             "What is the greenhouse effect?",
             "What is the best way to mitigate the effects of the greenhouse effect?",
             "What are the long-term effects of climate change?",
             "What is the best way to adapt to climate change?",
             "Why does earth have a magnetic field?",
             "What is the best way to protect the Earth's magnetic field?",
             "What is Ozone layer and why is it important?",
             "What is the best way to protect the Ozone layer?",
             "What are chlorofluorocarbons (CFCs) and why are they harmful to the Ozone layer?",
             "What is the best way to reduce the use of CFCs?",
             "Why were the CFCs used in the first place?",
             "Why did carbon dioxide levels rise during the Industrial Revolution?",
             "Where are dinosaur fossils found?",
             "What is the best way to preserve dinosaur fossils?",
             "When did the dinosaurs go extinct?",
             "What caused the extinction of the dinosaurs?",
             "What is the best way to study dinosaurs?",
             "What are the most important dinosaur discoveries?",
             "Is Jurassic Park scientifically accurate?",
             "What is the best way to create a dinosaur clone?",
             "What is the largest dinosaur ever discovered?"
             ]

# %%
print(len(questions))
# Out:
# 149

# %%
prompt = """
You are a Socratic, curiosity‑promoting learning companion.

Your goals:
1. Encourage the user to think before answering.
2. Promote a sense of wonder, exploration, and reflection.
3. Avoid giving direct answers unless the user explicitly asks for them.
4. Ask guiding questions that help the user form their own understanding.
5. Tailor your questions to the user’s level of knowledge and intent.
6. Always output your response in the required JSON format.

Behavior rules:
- Begin with a short, engaging statement or question that sparks curiosity.
- Ask 2–3 follow‑up questions that the user might naturally wonder about.
- These questions should broaden or deepen the topic.
- Do NOT provide a direct answer unless the user insists.
- Never break JSON format.

Required output format:
{
  "response": "<your curiosity‑promoting statement>",
  "suggested_questions": [
    "<question 1>",
    "<question 2>",
    "<question 3>"
  ]
}
"""

# %%
import os
import json
import google.generativeai as genai

# Setup Gemini credentials
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# Use gemini-2.5-flash-lite for faster iteration
model = genai.GenerativeModel("gemini-2.5-flash")

def generate_entry(question):
    # Combine system prompt and user question for the model input
    # Note: Gemini 1.5 also supports a 'system_instruction' argument in the constructor
    full_prompt = f"System: {prompt}\nUser: {question}"
    
    response = model.generate_content(full_prompt)
    assistant_reply = response.text.strip()
    
    # Structural mapping to your requested style
    return {
        "messages": [
            {"role": "system", "content": prompt},
            {"role": "user", "content": question},
            {"role": "assistant", "content": assistant_reply}
        ]
    }

# Process list and append to JSONL
with open("dataset.jsonl", "a", encoding="utf-8") as f:
    for q in questions:
        try:
            entry = generate_entry(q)
            f.write(json.dumps(entry) + "\n")
            print(f"Success: {q[:30]}...")
        except Exception as e:
            print(f"Failed on {q}: {e}")

print("\nAll entries appended to dataset.jsonl")
# Out:
# E0000 00:00:1771023674.856560 74924011 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Success: What is machine learning?...
# Success: What is deep learning?...
# Success: What is natural language proce...
# Success: What is computer vision?...
# Success: What is robotics?...
# Success: What is physics?...
# Failed on What is chemistry?: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in